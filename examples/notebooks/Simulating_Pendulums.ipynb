# %%
import hephaestus as hp
import matplotlib.pyplot as plt
import numpy as np

# %%
N=10000

# %%
pendulum = hp.SinglePendulum(time_step=0.001, steps=N, mass=1.0, gravity=10.0, theta_start=5.0)

# %%
integrator = hp.VelocityVerlet(time_step=0.001, model=pendulum)

# %%
pendulum.integrator = integrator

# %%
pendulum.run_simulation()

# %%
plt.plot(np.linspace(0, N, N), pendulum.pe, label='PE')
plt.plot(np.linspace(0, N, N), pendulum.ke, label='KE')
plt.legend()
plt.show()

# %%
plt.plot(np.linspace(0, N, N), pendulum.ke + pendulum.pe, label='total')
plt.legend()
plt.show()

# %%
pendulum.theta
# Out:
# array([0.08726646, 0.08726603, 0.08726472, ..., 0.08582037, 0.08576994,
#        0.08571866])
